# %% [markdown]
# # Load packages and settings

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import sys
# Path to the directory containing the code
sys.path.append('/content/drive/MyDrive/GitHub/WSOL-Weakly-Supervised-Object-Localization/PSOL')
sys.path.append('/content/drive/MyDrive/GitHub/WSOL-Weakly-Supervised-Object-Localization/PSOL/utils')

# %%
import os

# %%
data_path = '/content/drive/MyDrive/Colab Notebooks/CUB_200_2011' # Path to the root directory of the dataset 
ddt_path = '/content/drive/MyDrive/Colab Notebooks/BBs'
save_path = '/content/drive/MyDrive/Colab Notebooks/'

# %%
from generate_box import generate_box

# %% [markdown]
# # Generate Pseudo bounding boxes with DDT

# %%
generate_box(train_root, 448, 32, ddt_path)
# Out:
# Generating Pseudo BBs for class 0
# Generating Pseudo BBs for class 1
# Generating Pseudo BBs for class 2
# Generating Pseudo BBs for class 3
# Generating Pseudo BBs for class 4
# Generating Pseudo BBs for class 5
# Generating Pseudo BBs for class 6
# Generating Pseudo BBs for class 7
# Generating Pseudo BBs for class 8
# Generating Pseudo BBs for class 9
# Generating Pseudo BBs for class 10
# Generating Pseudo BBs for class 11
# Generating Pseudo BBs for class 12
# Generating Pseudo BBs for class 13
# Generating Pseudo BBs for class 14
# Generating Pseudo BBs for class 15
# Generating Pseudo BBs for class 16
# Generating Pseudo BBs for class 17
# Generating Pseudo BBs for class 18
# Generating Pseudo BBs for class 19
# Generating Pseudo BBs for class 20
# Generating Pseudo BBs for class 21
# Generating Pseudo BBs for class 22
# Generating Pseudo BBs for class 23
# Generating Pseudo BBs for class 24
# Generating Pseudo BBs for class 25
# Generating Pseudo BBs for class 26
# ...

# %% [markdown]
# # Training

# %%
from PSOL_training import train_psol

# %%
train_psol(data_path, ddt_path, save_path)
# Out:
# loading from ground truth bbox
# loading from ground truth bbox
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# ...
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %% [markdown]
# # Inference

# %%
from PSOL_inference import psol_infer

# %%
model_path = os.path.join(save_path, 'best_cls_localization_imagenet_ddt_resnet50_5.pth.tar')
psol_infer(data_path, 'resnet50', model_path, visualize=True, colab=True)
# Out:
# conv1.weight
# bn1.weight
# bn1.bias
# bn1.running_mean
# bn1.running_var
# bn1.num_batches_tracked
# layer1.0.conv1.weight
# layer1.0.bn1.weight
# layer1.0.bn1.bias
# layer1.0.bn1.running_mean
# layer1.0.bn1.running_var
# layer1.0.bn1.num_batches_tracked
# layer1.0.conv2.weight
# layer1.0.bn2.weight
# layer1.0.bn2.bias
# layer1.0.bn2.running_mean
# layer1.0.bn2.running_var
# layer1.0.bn2.num_batches_tracked
# layer1.0.conv3.weight
# layer1.0.bn3.weight
# layer1.0.bn3.bias
# layer1.0.bn3.running_mean
# layer1.0.bn3.running_var
# layer1.0.bn3.num_batches_tracked
# layer1.0.downsample.0.weight
# layer1.0.downsample.1.weight
# layer1.0.downsample.1.bias
# layer1.0.downsample.1.running_mean
# layer1.0.downsample.1.running_var
# layer1.0.downsample.1.num_batches_tracked
# layer1.1.conv1.weight
# layer1.1.bn1.weight
# layer1.1.bn1.bias
# layer1.1.bn1.running_mean
# layer1.1.bn1.running_var
# layer1.1.bn1.num_batches_tracked
# layer1.1.conv2.weight
# layer1.1.bn2.weight
# layer1.1.bn2.bias
# ...
