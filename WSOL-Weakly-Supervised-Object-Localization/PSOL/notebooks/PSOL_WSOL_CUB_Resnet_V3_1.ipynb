# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# # Set System Parameters for the PSOL Code

# %%
import os
import sys
# Path to the directory containing the code
sys.path.append('/content/drive/My Drive/fellowship/datasets/WSOL/PSOL/code/')
sys.path.append('/content/drive/My Drive/fellowship/datasets/WSOL/PSOL/code/utils/')

# %% [markdown]
# # PIP Install Dependencies

# %%
# !pip install -r requirements.txt
# !pip install opencv-contrib-python
# !pip install scikit-image

# %% [markdown]
# # Set Relevant Paths for the project.

# %%
Data_Path = '/content/drive/My Drive/fellowship/datasets/WSOL/PSOL/CUB_Data/'
DDT_Path = '/content/drive/My Drive/fellowship/datasets/WSOL/PSOL/code/ImageNet/Projection/VGG16-448/'
GT_Path  = '/content/drive/My Drive/fellowship/datasets/WSOL/PSOL/Imagenet_gt/'
Save_Path = '/content/drive/My Drive/fellowship/datasets/WSOL/PSOL/CUB_Data/visualization/'
Model_Path = '/content/drive/My Drive/fellowship/datasets/WSOL/PSOL/code/models/'
print("Data_Path ::",Data_Path)
print("DDT_Path ::",DDT_Path)
print("GT_Path ::",GT_Path)
print("Save_Path ::",GT_Path)
print("Save_Path ::",Model_Path)
# Out:
# Data_Path :: /content/drive/My Drive/fellowship/datasets/WSOL/PSOL/CUB_Data/
# DDT_Path :: /content/drive/My Drive/fellowship/datasets/WSOL/PSOL/code/ImageNet/Projection/VGG16-448/
# GT_Path :: /content/drive/My Drive/fellowship/datasets/WSOL/PSOL/Imagenet_gt/
# Save_Path :: /content/drive/My Drive/fellowship/datasets/WSOL/PSOL/Imagenet_gt/
# Save_Path :: /content/drive/My Drive/fellowship/datasets/WSOL/PSOL/code/models/

# %% [markdown]
# # Training

# %%
from generate_box_imagenet import generate_box
#!python generate_box_imagenet.py '/content/drive/My Drive/fellowship/datasets/WSOL/PSOL/CUB_Data/'
generate_box(Project_Path,Data_Path,num_classes=3)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# ...
# Generating Pseudo BBs for class 0
# Before PCA
# AFTER PCA
# trans_matrix shape is (1, 512)
# Generating Pseudo BBs for class 1
# Before PCA
# AFTER PCA
# trans_matrix shape is (1, 512)
# Generating Pseudo BBs for class 2
# Before PCA
# AFTER PCA
# trans_matrix shape is (1, 512)

# %%
#!python PSOL_training.py '/content/drive/My Drive/fellowship/datasets/WSOL/PSOL/CUB_Data/'
from PSOL_training import psol_trainig
#psol_trainig(Data_Path,DDT_Path,GT_Path)
psol_trainig(Data_Path,DDT_Path,GT_Path,locmodel='resnet50',input_size=256,crop_size=224,epochs=6,batch_size=64)
# Out:
# ****gt_location**** /content/drive/My Drive/fellowship/datasets/WSOL/PSOL/Imagenet_gt/
# ***gt_label*** {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Wed Mar 25 17:13:33 2015', '__version__': '1.0', '__globals__': [], 'rec': array([[(array([[(array([[490]], dtype=uint16), array([[111, 108, 441, 193]], dtype=uint16))]],
#       dtype=[('label', 'O'), ('bbox', 'O')]),),
#         (array([[(array([[361]], dtype=uint16), array([[ 45,  49, 499, 162]], dtype=uint16)),
#         (array([[361]], dtype=uint16), array([[  2,  69, 437, 207]], dtype=uint16))]],
#       dtype=[('label', 'O'), ('bbox', 'O')]),),
#         (array([[(array([[171]], dtype=uint8), array([[ 38,  19, 385, 373]], dtype=uint16))]],
#       dtype=[('label', 'O'), ('bbox', 'O')]),),
#         ...,
#         (array([[(array([[128]], dtype=uint8), array([[ 11,   2, 499, 335]], dtype=uint16))]],
#       dtype=[('label', 'O'), ('bbox', 'O')]),),
# ...

# %% [markdown]
# # Testing the PSOL model

# %%
import os
from PSOL_inference import psol_infer

model_path = os.path.join(Model_Path, 'resnet50loc.pth.tar')
psol_infer(data_path=Data_Path,model_path=model_path,savepath=Save_Path,num_classes=3,
           locmodel='resnet50',clsmodel='resnet50',input_size=256,
           crop_size=224,tencrop=False,visualize_pct=0.1,colab=True)
# Out:
# conv1.weight
# bn1.weight
# bn1.bias
# bn1.running_mean
# bn1.running_var
# bn1.num_batches_tracked
# layer1.0.conv1.weight
# layer1.0.bn1.weight
# layer1.0.bn1.bias
# layer1.0.bn1.running_mean
# layer1.0.bn1.running_var
# layer1.0.bn1.num_batches_tracked
# layer1.0.conv2.weight
# layer1.0.bn2.weight
# layer1.0.bn2.bias
# layer1.0.bn2.running_mean
# layer1.0.bn2.running_var
# layer1.0.bn2.num_batches_tracked
# layer1.0.conv3.weight
# layer1.0.bn3.weight
# layer1.0.bn3.bias
# layer1.0.bn3.running_mean
# layer1.0.bn3.running_var
# layer1.0.bn3.num_batches_tracked
# layer1.0.downsample.0.weight
# layer1.0.downsample.1.weight
# layer1.0.downsample.1.bias
# layer1.0.downsample.1.running_mean
# layer1.0.downsample.1.running_var
# layer1.0.downsample.1.num_batches_tracked
# layer1.1.conv1.weight
# layer1.1.bn1.weight
# layer1.1.bn1.bias
# layer1.1.bn1.running_mean
# layer1.1.bn1.running_var
# layer1.1.bn1.num_batches_tracked
# layer1.1.conv2.weight
# layer1.1.bn2.weight
# layer1.1.bn2.bias
# ...
